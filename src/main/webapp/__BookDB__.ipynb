# %%
import cx_Oracle
import os
import pandas as pd

datatest = pd.read_csv('1bookmodel.csv')
datatest
# Out:
#               book_name book_category  \
# 0                 리얼 제주         건강 취미
# 1               리얼 국내여행         건강 취미
# 2         에이든 국내여행 가이드북         건강 취미
# 3         에이든 제주여행 가이드북         건강 취미
# 4              초격차 다이어트         건강 취미
# ..                  ...           ...
# 741   한미란의 니트 교실 대바늘 뜨기         건강 취미
# 742         1日 1食 1일 1식         건강 취미
# 743  암, 투병하면 죽고 치병하면 산다         건강 취미
# 744           타로카드 완전정복         건강 취미
# 745    아사나 쁘라나야마 무드라 반다         건강 취미
#
#                                             book_intro  book_score  y
# 0    제주 토박이 여행 블로거와 이주 10년 차 여행작가가 큐레이션한\n제주를 가장 멋지...         9.8  1
# 1    숲길 산책부터 드라이브, 서핑 체험까지\n나만의 속도로 즐기는 우리나라 여행\n\n...         9.8  1
# 2    여행 베스트셀러 에이든 여행지도에서 2020년 8월 국내여행 가이드북을 정식 출간하...         9.4  0
# 3    에이든 제주여행 가이드북은 여행자들이 에이든 여행지도를 만들면서 수집했던 전국의 수...        10.0  1
# 4    당신이 단 한권의 다이어트 책을 가져야 한다면\n\n그동안 수많은 다이어트 책과 정...         9.6  1
# ..                                                 ...         ... ..
# ...

# %%
datatest.T.to_dict()
# Out:
# {0: {'book_name': '리얼 제주',
#   'book_category': '건강 취미',
#   'book_intro': '제주 토박이 여행 블로거와 이주 10년 차 여행작가가 큐레이션한\n제주를 가장 멋지게 여행하는 방법\n\n코로나19 팬데믹 시대, 막혀버린 해외여행의 대체지로 가장 많이 언급되고 있는 곳이 제주입니다. 하지만 제주는 어느 여행지의 대체지라기보다는 그 자체로 고유한 매력 넘치는 곳입니다.당신은 제주에 대해 얼마나 알고 있나요? 따뜻한 봄날, 흩날리는 벚꽃과 노란 유채꽃 흐드러진 들판에서 인생샷을 찍어 본 적 있나요? 시원한 여름, 하얀 백사장과 어우러진 에메랄드빛 바다에 풍덩 몸을 맡겨봐도 좋아요. 낭만적인 가을, 몽환적인 핑크뮬리와 억새 물결 속에서 감성 충전 제대로 할 수 있고요. 하얀 겨울 눈꽃 핀 한라산 등반은 진짜 제주를 느끼기에 최고입니다.\n\n이렇듯 다채로운 제주의 매력을 제주 토박이 제주 여행 블로거 양정임 작가(제주규리@jejuguree)와 이주 10년 차 여행작가 김태연 작가(제주레이@jejureigh)가 비슷한 듯 다른 시선으로 『리얼 제주』에서 꼼꼼하게 큐레이션 했습니다. 『리얼 제주』는 제주를 처음 여행하는 사람을 위한 필수 스폿과 음식부터 시내 교통, 숙소까지 자세히 다뤘습니다. 자주 찾는 여행자를 위해서는 계절별로 해야 할 버킷리스트와 월별 변화하는 볼거리, 먹거리를 반영한 월별 코스(총 8개)에도 심혈을 기울였습니다. 특히, 실제 여행에도 가볍게 휴대하기 쉽게 월별 여행 캘린더는 부록으로 한 번 더 제시했습니다. 지금의 제주를 가장 멋지게 여행하고 싶다면 바로 『리얼 제주』입니다.\n ',
#   'book_score': 9.8,
#   'y': 1},
#  1: {'book_name': '리얼 국내여행',
#   'book_category': '건강 취미',
# ...

# %%
list(datatest.T.to_dict().values())
# Out:
# [{'book_name': '리얼 제주',
#   'book_category': '건강 취미',
#   'book_intro': '제주 토박이 여행 블로거와 이주 10년 차 여행작가가 큐레이션한\n제주를 가장 멋지게 여행하는 방법\n\n코로나19 팬데믹 시대, 막혀버린 해외여행의 대체지로 가장 많이 언급되고 있는 곳이 제주입니다. 하지만 제주는 어느 여행지의 대체지라기보다는 그 자체로 고유한 매력 넘치는 곳입니다.당신은 제주에 대해 얼마나 알고 있나요? 따뜻한 봄날, 흩날리는 벚꽃과 노란 유채꽃 흐드러진 들판에서 인생샷을 찍어 본 적 있나요? 시원한 여름, 하얀 백사장과 어우러진 에메랄드빛 바다에 풍덩 몸을 맡겨봐도 좋아요. 낭만적인 가을, 몽환적인 핑크뮬리와 억새 물결 속에서 감성 충전 제대로 할 수 있고요. 하얀 겨울 눈꽃 핀 한라산 등반은 진짜 제주를 느끼기에 최고입니다.\n\n이렇듯 다채로운 제주의 매력을 제주 토박이 제주 여행 블로거 양정임 작가(제주규리@jejuguree)와 이주 10년 차 여행작가 김태연 작가(제주레이@jejureigh)가 비슷한 듯 다른 시선으로 『리얼 제주』에서 꼼꼼하게 큐레이션 했습니다. 『리얼 제주』는 제주를 처음 여행하는 사람을 위한 필수 스폿과 음식부터 시내 교통, 숙소까지 자세히 다뤘습니다. 자주 찾는 여행자를 위해서는 계절별로 해야 할 버킷리스트와 월별 변화하는 볼거리, 먹거리를 반영한 월별 코스(총 8개)에도 심혈을 기울였습니다. 특히, 실제 여행에도 가볍게 휴대하기 쉽게 월별 여행 캘린더는 부록으로 한 번 더 제시했습니다. 지금의 제주를 가장 멋지게 여행하고 싶다면 바로 『리얼 제주』입니다.\n ',
#   'book_score': 9.8,
#   'y': 1},
#  {'book_name': '리얼 국내여행',
#   'book_category': '건강 취미',
# ...

# %%
conn = cx_Oracle.connect("campus_e5","smhrd5","project-db-stu.ddns.net:1524/xe")
cs = conn.cursor()

# %%
sql_insert = 'insert into bookmodel1 (book_name, book_category, book_intro, book_score, y) values({:book_name, jdbcType=VARCHAR}, {:book_category, jdbcType=VARCHAR}, {:book_intro, jdbcType=VARCHAR}, {:book_score, jdbcType=VARCHAR}, {:y, jdbcType=VARCHAR})'
db = conn.cursor()

db.executemany(sql_insert,list(datatest.T.to_dict().values()))
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-4-dff653a38204> in <module>
#       2 db = conn.cursor()
#       3
# ----> 4 db.executemany(sql_insert,list(datatest.T.to_dict().values()))
#
# DatabaseError: ORA-01461: can bind a LONG value only for insert into a LONG column

# %%
datatest.T.to_dict()
# Out:
# {0: {'book_name': '리얼 제주',
#   'book_category': '건강 취미',
#   'book_intro': '제주 토박이 여행 블로거와 이주 10년 차 여행작가가 큐레이션한\n제주를 가장 멋지게 여행하는 방법\n\n코로나19 팬데믹 시대, 막혀버린 해외여행의 대체지로 가장 많이 언급되고 있는 곳이 제주입니다. 하지만 제주는 어느 여행지의 대체지라기보다는 그 자체로 고유한 매력 넘치는 곳입니다.당신은 제주에 대해 얼마나 알고 있나요? 따뜻한 봄날, 흩날리는 벚꽃과 노란 유채꽃 흐드러진 들판에서 인생샷을 찍어 본 적 있나요? 시원한 여름, 하얀 백사장과 어우러진 에메랄드빛 바다에 풍덩 몸을 맡겨봐도 좋아요. 낭만적인 가을, 몽환적인 핑크뮬리와 억새 물결 속에서 감성 충전 제대로 할 수 있고요. 하얀 겨울 눈꽃 핀 한라산 등반은 진짜 제주를 느끼기에 최고입니다.\n\n이렇듯 다채로운 제주의 매력을 제주 토박이 제주 여행 블로거 양정임 작가(제주규리@jejuguree)와 이주 10년 차 여행작가 김태연 작가(제주레이@jejureigh)가 비슷한 듯 다른 시선으로 『리얼 제주』에서 꼼꼼하게 큐레이션 했습니다. 『리얼 제주』는 제주를 처음 여행하는 사람을 위한 필수 스폿과 음식부터 시내 교통, 숙소까지 자세히 다뤘습니다. 자주 찾는 여행자를 위해서는 계절별로 해야 할 버킷리스트와 월별 변화하는 볼거리, 먹거리를 반영한 월별 코스(총 8개)에도 심혈을 기울였습니다. 특히, 실제 여행에도 가볍게 휴대하기 쉽게 월별 여행 캘린더는 부록으로 한 번 더 제시했습니다. 지금의 제주를 가장 멋지게 여행하고 싶다면 바로 『리얼 제주』입니다.\n ',
#   'book_score': 9.8,
#   'y': 1},
#  1: {'book_name': '리얼 국내여행',
#   'book_category': '건강 취미',
# ...

# %%
import csv

# %%
book_name = []
book_category = []
book_intro = []
book_score = []
y = []
rows=[]
with open('1bookmodel.csv', encoding='utf-8') as datatest:
    # raw = csv.reader(datatest)
    for row in csv.reader(datatest):
        dic = {}
        dic['book_name'] = row[0]
        # book_name.append(row[0])
        # book_category.append(row[1])
        # book_intro.append(row[2])
        # book_score.append(row[3])
        # y.append(row[4])

# %%
book_name
# Out:
# ['book_name',
#  '리얼 제주',
#  '리얼 국내여행',
#  '에이든 국내여행 가이드북',
#  '에이든 제주여행 가이드북',
#  '초격차 다이어트',
#  '아이랑 제주 여행',
#  '하루쯤 나 혼자 어디라도 가야겠다',
#  '자동차 구조 교과서',
#  '제주를 달리는 64가지 방법',
#  '운동화 신은 뇌',
#  '대한민국 트레킹 가이드',
#  '자동차 주말여행 코스북',
#  '에이든 우리나라 전국 여행지도',
#  '인체 구조 교과서',
#  '다정한 나의 오일파스텔',
#  '서울·경기·인천 트레킹 가이드',
#  '대한민국 오지여행',
#  '자전거 여행 바이블 국토종주편',
#  '맛불리 다이어트 연구소',
#  '즐거워, 빵과 커피가 있으면',
#  '비만의 사회학',
#  '관엽식물 가이드 155',
#  '52주 여행, 숨쉬고 물드는 제주도 531',
#  '전국도로지도',
#  '나의 첫 수채화 캘리그라피',
#  '나는 스마트폰으로 매일 인생사진 찍는다',
#  '프렌즈 미국 동부',
#  '아름다운 사찰여행',
#  '스티커 아트북 : 아이 러브 애니멀',
#  '대한민국 자동차 캠핑 가이드',
#  '지리 덕후가 떠먹여주는 풀코스 세계지리',
#  '자동차 정비 교과서',
#  '특별하게 제주',
#  '국내여행 버킷리스트 101',
#  '자전거 여행 바이블 수도권편',
#  '포르투갈에 물들다',
#  '우리가 몰랐던 백신의 놀라운 비밀',
#  '미쉐린 가이드 서울 2021',
#  '무작정 따라하기 하와이',
#  '다육식물도감',
#  '1일 1장 만다라',
#  '오늘부터 차박캠핑',
#  '당신의 몸짓은 개에게 무엇을 말하는가?',
#  '유럽여행 바이블',
#  '제주올레 인문 여행',
#  '프렌즈 제주',
#  '인체 면역학 교과서',
#  '대한민국 섬 여행 가이드',
#  '슈퍼 스도쿠 익스트림',
#  '라탄으로 만드는 감성 소품',
#  '처음 배우는 오일파스텔',
# ...

# %%
#type(book_name[0])
#type(book_category[0])
#type(book_intro[0])
type(book_score[0])
# Out:
# str

# %%
type(y[0])
# Out:
# str

# %%
import requests
import urllib
import cx_Oracle
import os
import chardet
from openpyxl import Workbook
from bs4 import BeautifulSoup

os.environ["NLS_LANG"] = ".AL32UTF8"

wb = Workbook()

ws = wb.active
ws.title = "first_Steet"
# 에겔 컬럼에 따른 컬럼명
ws["A1"] = "brand"
ws["B1"] = "name"
ws["C1"] = "price"
ws["D1"] = "src"

# %%
list_1 = []
conn = cx_Oracle.connect("campus_e5","smhrd5","project-db-stu.ddns.net:1524/xe")
cs = conn.cursor()

sql_insert = cs.execute("""
                        insert into bookmodel1 
                        (book_name, book_category, book_intro, book_score, y)
                        values (:1,:2,:3,:4,:5)
                        """)
cs.execute(sql,('3','3','1'))

for record in sql_insert:
    list_1.append(record)

print(list_1)

# %%
def sql_insert

# %%
sql_insert = 'insert into bookmodel1 (book_name, book_category, book_intro, book_score, y) values(%s, %s, %s, %s, %s)'
db = connect.cursor()

# %%
connect.commit()

# %%
sql_insert = 'insert into bookmodel1 (book_name, book_category, book_intro, book_score, y) values(:book_name, :book_category, :book_intro, :book_score, :y)'
db = connect.cursor()


db.executemany(sql_insert,list(datatest.T.to_dict().values()))
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-149-7f6da8209af2> in <module>
#       3
#       4
# ----> 5 db.executemany(sql_insert,list(datatest.T.to_dict().values()))
#       6
#       7 datatest.T.to_dict()
#
# DatabaseError: ORA-12899: value too large for column "CAMPUS_E5"."BOOKMODEL1"."BOOK_INTRO" (actual: 2121, maximum: 2000)

# %%
list_1 = []

sql_insert = 'insert into bookmodel1 book_name, book_category, book_intro, book_score, y, values(%s, %s, %s, %s, %s)'
db = connect.cursor()

db.execute(sql_insert, book_name, book_category, book_intro, book_score, y)

connect.commit()

db.execute('SELECT * FROM bookmodel1')

for record in db:
    list_1.append(record)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-d221512ef390> in <module>
#       2 db = connect.cursor()
#       3
# ----> 4 db.execute(sql_insert, book_name, book_category, book_intro, book_score, y)
#       5
#       6 connect.commit()
#
# TypeError: function takes at most 2 arguments (6 given)

# %%
book_name = []
book_category = []
book_intro = []
book_score = []
y = []

with open('1bookmodel.csv', encoding='utf-8') as f:
    raw = csv.reader(f)
    for i in range(len(testdate)):
        for row in raw:
            book_name = (row[0][i])
            book_category = (row[1][i])
            book_intro = (row[2][i])
            book_score = (row[3][i])
            y = (row[4][i])
        print(book_name)
        print(book_category)
        print(book_intro)
        print(book_score)
        print(y)
# Out:
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# 아
# 건
# 1
# 6
# 0
# ...

# %%
y
# Out:
# '0'

# %%
csvReader = csv.reader(datatest)
len(csvReader)

# %%
csvReader = csv.reader(datatest)

dataset = []

for i in range(5):
    raw
for row in csvReader:
    book_name = (row[0])
    book_category = (row[1])
    book_intro = (row[2])
    book_score = (row[3])
    y = (row[4])

    sql = """
        insert into bookmodel1 (book_name, book_category, book_intro, book_score, y)
        values(%s, %s, %s, %s, %s)
    """
    cursor.execute(sql, (book_name, book_category, book_intro, book_score, y))

connect.commit()

connect.close()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-0aa3614fbb2f> in <module>
#       3 for row in csvReader:
#       4     book_name = (row[0])
# ----> 5     book_category = (row[1])
#       6     book_intro = (row[2])
#       7     book_score = (row[3])
#
# IndexError: list index out of range
